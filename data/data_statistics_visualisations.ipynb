# %% [markdown]
# # Import

# %%
import sys
sys.path.append('../')
from mylibs import *

# %% [markdown]
# # Data

# %%
from data import Data
handler = Data()
data = handler.load('../artifacts_5s_128hz.pkl')
train_split, val_split, test_split = handler.split(data)

# %% [markdown]
# # Plot of datasample with artifacts

# %%
handler.plot(data[20,:,:])

# %% [markdown]
# # Class balance

# %% [markdown]
# ## Without undersampling

# %%
_, train_labels = handler.prepare_data(train_split, balance=False, dataset=False)
handler.get_balance(train_labels)
# Out:
# Balance:
#     Count of Timesteps with no artifacts at all: 143636130
#     Count Timesteps with artifacts: 15616350 (9.81% of total)

# %% [markdown]
# ## With undersampling

# %%
_, train_labels_balanced = handler.prepare_data(train_split, balance=True, dataset=False)
handler.get_balance(train_labels_balanced)
# Out:
# Balance:
#     Count of Timesteps with no artifacts at all: 28532130
#     Count Timesteps with artifacts: 15616350 (35.37% of total)
